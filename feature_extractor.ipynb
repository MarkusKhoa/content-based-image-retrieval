# %%
import tensorflow as tf
import os
import numpy as np
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from utils import folder_to_images

# %%
class FeatureExtractor:
    def __init__(self):
        base_model = ResNet50(weights="imagenet", include_top=False)
        x = base_model.output
        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        self.model = tf.keras.Model(inputs=base_model.input, outputs=x)
        
    def extract(self, img):
        
        x = preprocess_input(img)
        feature = self.model.predict(x)  
        return feature

# %%
imgs_feature = []
paths_feature = []
FE = FeatureExtractor()

# %%
root_images_path = "./images/"
saved_features_path = "./feature/"
os.makedirs(saved_features_path, exist_ok = True)
categories = ["animal", "country", "furniture", "plant", "scenery"]
img_size = (224, 224)

# %%
for folder in os.listdir(root_images_path):
    if folder.split("_")[0] in categories:
        try:
            path = root_images_path + folder + "/"
            images_np, images_path = folder_to_images(path)
            paths_feature.extend(np.array(images_path))
            imgs_feature.extend(FE.extract(images_np))
            print(f"Extract features successfully at {path} path") 
        except Exception:
            print(f"Cannot extract features at {path} path because of empty folder")
            pass
# Out:
# Extract features successfully at ./images/animal_Alligator/ path
# Extract features successfully at ./images/animal_Alpaca/ path
# Cannot extract features at ./images/animal_Anteater/ path because of empty folder
# Extract features successfully at ./images/animal_Ants/ path
# Extract features successfully at ./images/animal_Bats/ path
# Extract features successfully at ./images/animal_bear/ path
# Extract features successfully at ./images/animal_Bee/ path
# Extract features successfully at ./images/animal_bird/ path
# Extract features successfully at ./images/animal_Buffalo/ path
# Extract features successfully at ./images/animal_Butterfly/ path
# Extract features successfully at ./images/animal_Camel/ path
# Extract features successfully at ./images/animal_Cat/ path
# Extract features successfully at ./images/animal_Caterpillar/ path
# Extract features successfully at ./images/animal_Cheetah/ path
# Extract features successfully at ./images/animal_Chicken/ path
# Extract features successfully at ./images/animal_Civet/ path
# Extract features successfully at ./images/animal_Cock/ path
# Extract features successfully at ./images/animal_Cockroaches/ path
# Extract features successfully at ./images/animal_Coral/ path
# Extract features successfully at ./images/animal_cows/ path
# Extract features successfully at ./images/animal_Crab/ path
# Extract features successfully at ./images/animal_Dog/ path
# Extract features successfully at ./images/animal_donkey/ path
# Extract features successfully at ./images/animal_Dragonfly/ path
# Extract features successfully at ./images/animal_Duck/ path
# Extract features successfully at ./images/animal_Elephant/ path
# Extract features successfully at ./images/animal_Fish/ path
# Extract features successfully at ./images/animal_flamingo/ path
# Extract features successfully at ./images/animal_Flies/ path
# Extract features successfully at ./images/animal_fox/ path
# Extract features successfully at ./images/animal_Frog/ path
# Extract features successfully at ./images/animal_Giraffe/ path
# Extract features successfully at ./images/animal_horse/ path
# Extract features successfully at ./images/animal_Jellyfish/ path
# Extract features successfully at ./images/animal_Lizard/ path
# Extract features successfully at ./images/animal_Monkey/ path
# Extract features successfully at ./images/animal_Mosquito/ path
# Extract features successfully at ./images/animal_Owl/ path
# Extract features successfully at ./images/animal_panda/ path
# Cannot extract features at ./images/animal_Pangolins/ path because of empty folder
# Extract features successfully at ./images/animal_pig/ path
# Extract features successfully at ./images/animal_Rabbit/ path
# Extract features successfully at ./images/animal_scorpion/ path
# Extract features successfully at ./images/animal_shrimp/ path
# Extract features successfully at ./images/animal_Snail/ path
# Extract features successfully at ./images/animal_Snake/ path
# Extract features successfully at ./images/animal_Spider/ path
# Extract features successfully at ./images/animal_tiger/ path
# Extract features successfully at ./images/animal_Turtle/ path
# Extract features successfully at ./images/animal_Whale/ path
# Extract features successfully at ./images/country_Afghanistan/ path
# Extract features successfully at ./images/country_Albania/ path
# Extract features successfully at ./images/country_Canada/ path
# Extract features successfully at ./images/country_China/ path
# Extract features successfully at ./images/country_France/ path
# Extract features successfully at ./images/country_Germany/ path
# Extract features successfully at ./images/country_Hungary/ path
# Extract features successfully at ./images/country_Indonesia/ path
# Extract features successfully at ./images/country_Japan/ path
# Extract features successfully at ./images/country_Kazakhstan/ path
# Extract features successfully at ./images/country_Korea/ path
# Extract features successfully at ./images/country_Malaysia/ path
# Extract features successfully at ./images/country_Mexico/ path
# Extract features successfully at ./images/country_Poland/ path
# Extract features successfully at ./images/country_Qatar/ path
# Extract features successfully at ./images/country_Romania/ path
# Extract features successfully at ./images/country_Russia/ path
# Extract features successfully at ./images/country_Singapore/ path
# Extract features successfully at ./images/country_Thailand/ path
# Extract features successfully at ./images/country_UK/ path
# Extract features successfully at ./images/country_Ukraine/ path
# Extract features successfully at ./images/country_USA/ path
# Extract features successfully at ./images/country_Vietnam/ path
# Extract features successfully at ./images/country_Yemen/ path
# Extract features successfully at ./images/furniture_ball/ path
# Extract features successfully at ./images/furniture_bed/ path
# Extract features successfully at ./images/furniture_book/ path
# Extract features successfully at ./images/furniture_Bookcase/ path
# Extract features successfully at ./images/furniture_Bowl/ path
# Extract features successfully at ./images/furniture_cabinet/ path
# Extract features successfully at ./images/furniture_cart/ path
# Extract features successfully at ./images/furniture_chair/ path
# Extract features successfully at ./images/furniture_chests/ path
# Extract features successfully at ./images/furniture_clock/ path
# Extract features successfully at ./images/furniture_Clothes/ path
# Extract features successfully at ./images/furniture_desks/ path
# Extract features successfully at ./images/furniture_fridge/ path
# Extract features successfully at ./images/furniture_pan/ path
# Extract features successfully at ./images/furniture_Piano/ path
# Extract features successfully at ./images/furniture_sofa/ path
# Extract features successfully at ./images/furniture_spoon/ path
# Extract features successfully at ./images/furniture_table/ path
# Extract features successfully at ./images/furniture_Umbrella/ path
# Extract features successfully at ./images/plant_Apple/ path
# Extract features successfully at ./images/plant_Apricot/ path
# Extract features successfully at ./images/plant_Bamboo/ path
# Extract features successfully at ./images/plant_Banana/ path
# Extract features successfully at ./images/plant_Bean/ path
# Extract features successfully at ./images/plant_Bougainvillea/ path
# Extract features successfully at ./images/plant_carrot/ path
# Extract features successfully at ./images/plant_Clove/ path
# Extract features successfully at ./images/plant_Coconut/ path
# Cannot extract features at ./images/plant_Coffee_plant/ path because of empty folder
# Extract features successfully at ./images/plant_Corn/ path
# Cannot extract features at ./images/plant_Cornelian_tree/ path because of empty folder
# Cannot extract features at ./images/plant_Cotton_plant/ path because of empty folder
# Extract features successfully at ./images/plant_Dogwood/ path
# Extract features successfully at ./images/plant_Durian/ path
# Extract features successfully at ./images/plant_Fern/ path
# Extract features successfully at ./images/plant_Ferns/ path
# Extract features successfully at ./images/plant_Fig/ path
# Extract features successfully at ./images/plant_Flax/ path
# Extract features successfully at ./images/plant_Flower/ path
# Extract features successfully at ./images/plant_Frangipani/ path
# Extract features successfully at ./images/plant_Grass/ path
# Extract features successfully at ./images/plant_Hibiscus/ path
# Cannot extract features at ./images/plant_Jack_fruit/ path because of empty folder
# Extract features successfully at ./images/plant_Lantana/ path
# Extract features successfully at ./images/plant_Moss/ path
# Extract features successfully at ./images/plant_Mushroom/ path
# Cannot extract features at ./images/plant_Orchid_Tree/ path because of empty folder
# Cannot extract features at ./images/plant_Palm_tree/ path because of empty folder
# Extract features successfully at ./images/plant_Pea/ path
# Extract features successfully at ./images/plant_radish/ path
# Cannot extract features at ./images/plant_Rangoon_Creeper/ path because of empty folder
# Extract features successfully at ./images/plant_Reed/ path
# Extract features successfully at ./images/plant_Rose/ path
# Extract features successfully at ./images/plant_Shrub/ path
# Extract features successfully at ./images/plant_Tulip/ path
# Extract features successfully at ./images/plant_watermelon/ path
# Extract features successfully at ./images/plant_Weed/ path
# Extract features successfully at ./images/plant_wheat/ path
# Extract features successfully at ./images/plant_Wildflower/ path
# Extract features successfully at ./images/scenery_Bay/ path
# Extract features successfully at ./images/scenery_cave/ path
# Extract features successfully at ./images/scenery_Cliff/ path
# Extract features successfully at ./images/scenery_cloud/ path
# Extract features successfully at ./images/scenery_Coast/ path
# Extract features successfully at ./images/scenery_desert/ path
# Extract features successfully at ./images/scenery_farmland/ path
# Cannot extract features at ./images/scenery_flower_garden/ path because of empty folder
# Extract features successfully at ./images/scenery_Forests/ path
# Extract features successfully at ./images/scenery_glacier/ path
# Extract features successfully at ./images/scenery_grassland/ path
# Extract features successfully at ./images/scenery_hedges/ path
# Extract features successfully at ./images/scenery_horizon/ path
# Extract features successfully at ./images/scenery_Lake/ path
# Extract features successfully at ./images/scenery_lighthouse/ path
# Extract features successfully at ./images/scenery_Mountains/ path
# Extract features successfully at ./images/scenery_plain/ path
# Extract features successfully at ./images/scenery_plateau/ path
# Extract features successfully at ./images/scenery_river/ path
# Extract features successfully at ./images/scenery_savannah/ path
# Extract features successfully at ./images/scenery_sky/ path
# Extract features successfully at ./images/scenery_valley/ path
# Extract features successfully at ./images/scenery_volcano/ path
# Cannot extract features at ./images/scenery_Waterbodies/ path because of empty folder
# Extract features successfully at ./images/scenery_waterfall/ path

# %%
np.savez_compressed(saved_features_path+"all_feartures", array1=np.array(paths_feature), array2=np.array(imgs_feature))

# %%
root_features_path = "./feature/all_feartures.npz"
data = np.load(root_features_path)
paths_feature = data["array1"]
imgs_feature = data["array2"]
